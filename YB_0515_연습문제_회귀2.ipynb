# %% [markdown]
# <a href="https://colab.research.google.com/github/yuniecorn-dev/esaa_assignment/blob/main/YB_0515_%EC%97%B0%EC%8A%B5%EB%AC%B8%EC%A0%9C_%ED%9A%8C%EA%B7%802.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1. 규제 선형 회귀 모델/ 회귀 트리**
# - 릿지 회귀모델 및 회귀 트리를 이용하여 전복의 나이를 예측해 보세요.
#
# - 전복의 ‘성별’, ‘키’, ‘지름’, ‘높이’, ‘전체무게’, ‘몸통무게’, ‘내장무게’, ‘껍질무게’를 이용해 ‘껍질의 고리수’를 예측한 뒤, **예측된 ‘껍질의 고리수’에 1.5를 더하면 전복의 나이**가 됩니다.

# %%
# 기본 모듈 불러오기
import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# ### 1) 데이터 불러오기 및 데이터 선택

# %%
# 데이터 로드
data = pd.read_csv("abalone.csv")

# 성별 M은 Male, F는 Female, I는 Infant 이므로 따로 열 만들기
for label in "MFI":
    data[label] = data["Sex"] == label
data.drop('Sex', axis=1, inplace=True)

# X,y 데이터 선택
y = data.Rings.values
data.drop('Rings', axis=1, inplace=True)

X = data.values.astype(float)

# %% [markdown]
# ## 2) train/test 분리
# : 테스트 셋과 데이터 셋을 7:3 비율로 분리하세요.

# %%
# 필요한 모듈 불러오기
from sklearn.model_selection import train_test_split

# %%
# train과 test set 분리 (train:test = 7:3 비율로)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# ## 3) 릿지 모델을 이용한 모델링
# : 릿지 모델을 이용하여 전복의 나이를 예측해 보고 결과를 평가해 보세요.

# %% [markdown]
#  3-1) 릿지모델 생성, 교차검증, 평가에 필요한 모듈을 불러오세요.

# %%
#필요한 모듈 불러오기
from sklearn.linear_model import Ridge
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error

# %% [markdown]
# 3-2) 릿지 모델을 생성하고 훈련하여 MSE와 RMSE를 구하세요. 릿지 모델 생성 시  alpha는 0.3으로 설정합니다. (교차 검증 하지 않습니다.)

# %%
#릿지모델 생성 및 훈련
ridge = Ridge(alpha=0.3)
ridge.fit(X_train, y_train)

#예측값 구하기
y_pred = ridge.predict(X_test)

#구한 예측값을 활용해 최종적으로 전복의 나이 예측
age_pred = y_pred + 1.5
age_test = y_test + 1.5

#MSE와 RMSE구하기
mse = mean_squared_error(age_test, age_pred)
rmse = np.sqrt(mse)
print(f'MSE: {mse:.4f}, RMSE: {rmse:.4f}')
# Out:
# MSE: 4.7721, RMSE: 2.1845

# %% [markdown]
# 3-3) 릿지 모델에서 회귀 계수 값을 구해 알 수 있는 점을 작성하시오. (각 컬럼의 정보는 data.colums 참고)

# %%
data.columns
# Out:
# Index(['Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
#        'Viscera weight', 'Shell weight', 'M', 'F', 'I'],
#       dtype='object')

# %% [markdown]
# 3-3) 교차검증을 이용하여 0, 0.1, 1, 10, 100 중  모델 성능이 가장 좋게 나오는 (rmse가 최소가 되는) alpha를 구하세요.

# %%
# 주어진 alpha
alphas=[0, 0.1, 1, 10, 100]

# %%
#alphas list 값을 반복하면서 alpha에 따른 평균 rmse를 구함
for alpha in alphas:
    ridge = Ridge(alpha=alpha)

  #cross_val_score를 이용해 5 폴드의 평균 RMSE를 계산
    neg_mse_scores = cross_val_score(ridge, X, y, scoring="neg_mean_squared_error", cv=5)
    rmse_scores = np.sqrt(-1 * neg_mse_scores)
    avg_rmse = np.mean(rmse_scores)

    print(f'alpha {alpha} 일 때 5 folds 의 평균 RMSE : {avg_rmse:.4f}')
# Out:
# alpha 0 일 때 5 folds 의 평균 RMSE : 2.2446
# alpha 0.1 일 때 5 folds 의 평균 RMSE : 2.2371
# alpha 1 일 때 5 folds 의 평균 RMSE : 2.2303
# alpha 10 일 때 5 folds 의 평균 RMSE : 2.3373
# alpha 100 일 때 5 folds 의 평균 RMSE : 2.6212

# %% [markdown]
# ## 4) XGBRegressor을 이용한 모델링
# : XGBRegressor 모델을 이용하여 전복의 나이를 예측해 보고 결과를 평가해 보세요.

# %% [markdown]
# 4-1) XGBRegressor 훈련, 평가에 필요한 모듈을 불러오세요.

# %%
# 필요한 모듈 임포트
from xgboost import XGBRegressor

# %% [markdown]
# 4-2) XGBregressor 모델을 생성하고 훈련하여 MSE와 RMSE를 구하세요.

# %%
#모델 생성 및 훈련
xgb_reg = XGBRegressor(n_estimators=100, random_state=42)
xgb_reg.fit(X_train, y_train)

#예측값 구하기
xgb_pred = xgb_reg.predict(X_test)

#구한 예측값을 활용해 최종적으로 전복의 나이 예측
xgb_age_pred = xgb_pred + 1.5
xgb_age_test = y_test + 1.5

#MSE와 RMSE 구하기
xgb_mse = mean_squared_error(xgb_age_test, xgb_age_pred)
xgb_rmse = np.sqrt(xgb_mse)
print(f'XGBRegressor MSE: {xgb_mse:.4f}, RMSE: {xgb_rmse:.4f}')
# Out:
# XGBRegressor MSE: 5.5060, RMSE: 2.3465

# %% [markdown]
# 4-3) 생성한 모델의 피처 중요도를 시각화해보세요.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# 피처 중요도 추출 및 Series로 변환
ftr_importances_values = xgb_reg.feature_importances_
ftr_importances = pd.Series(ftr_importances_values, index=data.columns)

# 중요도 순으로 정렬
ftr_top = ftr_importances.sort_values(ascending=False)

# 시각화
plt.figure(figsize=(8, 6))
plt.title('Feature Importances')
sns.barplot(x=ftr_top, y=ftr_top.index)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # **2. 로지스틱 회귀분석**
# load_wine() 함수를 이용하여 와인 데이터를 다항분류하는 로지스틱 회귀모델을 생성하세요.

# %%
# 필요한 모듈 불러오기
from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

# %% [markdown]
# ## 1) 데이터 불러오기 및 변수 선택

# %%
wine = load_wine()

wine_x = wine.data # x변수
wine_y = wine.target # y변수

# %% [markdown]
# ## 2) train/test 셋 분리

# %%
x_train, x_test, y_train, y_test = train_test_split(wine_x, wine_y, test_size=0.3, random_state=123)

x_train.shape
y_train.shape
# Out:
# (124,)

# %% [markdown]
# ## 3) 로지스틱 회귀모델을 이용한 모델링

# %% [markdown]
# 3-1) 로지스틱 회귀모델을 생성하여 훈련하세요.

# %%
lr = LogisticRegression(max_iter=10000, random_state=123)
lr.fit(x_train, y_train)
# Out:
# LogisticRegression(max_iter=10000, random_state=123)

# %% [markdown]
# 3-2) 회귀 모델의 기울기와 절편을 구하세요.

# %%
#기울기
print(lr.coef_)
# Out:
# [[ 0.42439298  0.54744452  0.62026175 -0.25946906 -0.00207495  0.25257608
#    0.75790461  0.09118418  0.14341218  0.1758945  -0.01150508  0.51869373
#    0.00865839]
#  [-0.61350726 -0.91046142 -0.69744893  0.14881052 -0.04174846  0.31231432
#    0.15345516  0.03003637  0.39268846 -0.9168763   0.32597234  0.13224331
#   -0.00767599]
#  [ 0.18911428  0.3630169   0.07718717  0.11065854  0.0438234  -0.5648904
#   -0.91135977 -0.12122055 -0.53610064  0.7409818  -0.31446726 -0.65093704
#   -0.0009824 ]]

# %%
#절편
print(lr.intercept_)
# Out:
# [-13.57617163  21.30986693  -7.73369529]

# %% [markdown]
# 3-3) 모델의 정확도를 구하세요.

# %%
#모델의 예측값 구하기
y_pred = lr.predict(x_test)

#모델의 정확도 구하기
accuracy = metrics.accuracy_score(y_test, y_pred)
print(f"모델의 정확도: {accuracy:.4f}")
# Out:
# 모델의 정확도: 0.9630
